# %%
#get NLP libraries
import nltk
from nltk.tokenize import sent_tokenize
from newspaper import Article
import spacy
import neuralcoref


#get selenium and associated packages
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from time import sleep

#analysis packages
import pandas as pd
import numpy as np

#everything else
from itertools import product
from more_itertools import unique_everseen
import json

#spacy stuff
nlp = spacy.load('en_core_web_sm')
coref = neuralcoref.NeuralCoref(nlp.vocab)
nlp.add_pipe(coref, name='neuralcoref')

# %%
def clip_search(query, number):
    
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    driver = webdriver.Chrome('/Users/arijitsen/Downloads/chromedriver')
    
    driver.get('http://www.google.com')

    search_query = driver.find_element_by_name('q')

    search_query.send_keys(query)
    sleep(5)
    search_query.send_keys(Keys.RETURN)

    news_urls = []

    news_section = driver.find_elements_by_class_name('hdtb-mitem')
    counter = 0
    for i in news_section:
        if counter == 1:
            elements = i.find_elements_by_tag_name("a")
            for j in elements:
                x = j.get_attribute("href")
                driver.get(x)
            counter += 1
        else: 
            counter += 1

    content_blocks = driver.find_elements_by_class_name('ftSUBd')

    for block in content_blocks:
        elements = block.find_elements_by_tag_name("a")
        for el in elements:
            news_urls.append(el.get_attribute("href"))


    try:
        while len(news_urls) < count:
            next_button = driver.find_element_by_id('pnnext')
            next_button.click()
            news_section = driver.find_elements_by_class_name('hdtb-mitem')
            counter = 0
            for i in news_section:
                if counter == 1:
                    elements = i.find_elements_by_tag_name("a")
                    for j in elements:
                        x = j.get_attribute("href")
                        driver.get(x)
                    counter += 1
                else: 
                    counter += 1

            content_blocks = driver.find_elements_by_class_name('ftSUBd')

            for block in content_blocks:
                elements = block.find_elements_by_tag_name("a")
                for el in elements:
                    news_urls.append(el.get_attribute("href"))
            sleep(5)
    except:
        pass

    driver.quit()

    nodes = []

    urls = []
    sent_idx = []
    toke_idx = []

    corefs = []
    coref_idx = []
    urls1 = []
    for i in news_urls:
        try:
            article = Article(i)
            article.download()
            article.parse()
            article.nlp()

            #get the full text of the article
            text = article.text

            doc = nlp(text)

            tokenizer = nlp.tokenizer 

            sents = sent_tokenize(doc.text)
            
            counter = 0
            
            for j,k in enumerate(sents):

                x = tokenizer(k) #split sent into words
                
                sent_idx += len(x) * [j]

                for l in x:
                    counter += 1
                    toke_idx.append((counter - 1))
                    urls.append(i)
        
            for idx, chain in enumerate(doc._.coref_clusters):
                for mention in chain.mentions:
                    coref_idx.append(idx)
                    corefs.append(mention.start)
                    urls1.append(i)
                    


            for k, l in enumerate(sents):

                #Use Spacy to extract all the entities from the sentence and them add them to the entities list
                entity = nlp(l)


                for ee in entity.ents:
                    ent_dict = {}
                    #we only want person or organization entities
                    if ee.label_ == 'PERSON':
                        ent_dict['name'] = ee.text.replace('\n',' ').replace("'s'", "").strip()
                        ent_dict['label'] = ee.label_
                        ent_dict['sent_idx'] = k
                        ent_dict['start'] = ee.start
                        ent_dict['end'] = ee.end
                        ent_dict['urls'] = i
                        nodes.append(ent_dict)
                    elif ee.label_ == 'ORG':
                        ent_dict['name'] = ee.text.replace('\n',' ').replace("'s", "").strip()
                        ent_dict['label'] = ee.label_
                        ent_dict['sent_idx'] = k 
                        ent_dict['start'] = ee.start
                        ent_dict['end'] = ee.end
                        ent_dict['urls'] = i
                        nodes.append(ent_dict)
                    else:
                        pass
        except:
            pass
    return nodes

# %%
clip_search('"Social Sentinel"', 30)
# Out:
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if __name__ == '__main__':
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py:359: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:29: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [{'name': 'Social Media Security Market',
#   'label': 'ORG',
#   'sent_idx': 1,
#   'start': 0,
#   'end': 4,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Request',
#   'label': 'ORG',
#   'sent_idx': 5,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Download Sample of This',
#   'label': 'ORG',
#   'sent_idx': 5,
#   'start': 2,
#   'end': 6,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Information and Communications Technology Market',
#   'label': 'ORG',
#   'sent_idx': 6,
#   'start': 13,
#   'end': 18,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'ICT',
#   'label': 'ORG',
#   'sent_idx': 6,
#   'start': 19,
#   'end': 20,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Request',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Download Sample of This',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 2,
#   'end': 6,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Global',
#   'label': 'ORG',
#   'sent_idx': 19,
#   'start': 4,
#   'end': 5,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Asia Pacific',
#   'label': 'ORG',
#   'sent_idx': 19,
#   'start': 17,
#   'end': 19,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Download Free Sample Report',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 0,
#   'end': 4,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'report@:-https://reportocean.com',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 18,
#   'end': 19,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Micro Focus',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 42,
#   'end': 45,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'ZeroFox',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 51,
#   'end': 52,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'SolarWinds',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 55,
#   'end': 56,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Digital',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 57,
#   'end': 58,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'LookingGlass Cyber Solutions',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 62,
#   'end': 65,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'DigitalStakeout  Bowline Security',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 76,
#   'end': 80,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Sample',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 86,
#   'end': 87,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Monitoring',
#   'label': 'PERSON',
#   'sent_idx': 25,
#   'start': 20,
#   'end': 22,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Threat Intelligence',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 23,
#   'end': 25,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Cloud Security',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 55,
#   'end': 58,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Medium-Sized Enterprises',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 78,
#   'end': 83,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Financial Services',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 94,
#   'end': 96,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Insurance',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 98,
#   'end': 100,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Healthcare',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 101,
#   'end': 102,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Retail',
#   'label': 'PERSON',
#   'sent_idx': 25,
#   'start': 109,
#   'end': 111,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Media and Entertainment',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 112,
#   'end': 116,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Hospitality',
#   'label': 'PERSON',
#   'sent_idx': 25,
#   'start': 125,
#   'end': 127,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Asia Pacific',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 169,
#   'end': 171,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'the World  Furthermore,',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 194,
#   'end': 199,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Key Consulting Companies & Advisors',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 242,
#   'end': 247,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Value-Added Resellers',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 264,
#   'end': 268,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Final Report',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 298,
#   'end': 300,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'CAGR',
#   'label': 'ORG',
#   'sent_idx': 40,
#   'start': 21,
#   'end': 22,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Market',
#   'label': 'PERSON',
#   'sent_idx': 41,
#   'start': 4,
#   'end': 5,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Report Description',
#   'label': 'PERSON',
#   'sent_idx': 54,
#   'start': 2,
#   'end': 4,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'TOC',
#   'label': 'ORG',
#   'sent_idx': 54,
#   'start': 5,
#   'end': 6,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Table of Figure',
#   'label': 'ORG',
#   'sent_idx': 54,
#   'start': 7,
#   'end': 10,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Chart',
#   'label': 'PERSON',
#   'sent_idx': 54,
#   'start': 11,
#   'end': 12,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'SWOT',
#   'label': 'ORG',
#   'sent_idx': 59,
#   'start': 1,
#   'end': 2,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Porter’s Five Force',
#   'label': 'ORG',
#   'sent_idx': 59,
#   'start': 7,
#   'end': 11,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Market',
#   'label': 'ORG',
#   'sent_idx': 60,
#   'start': 10,
#   'end': 11,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Report Ocean',
#   'label': 'ORG',
#   'sent_idx': 62,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.taiwannews.com.tw/en/news/4377406'},
#  {'name': 'Dallas Morning News',
#   'label': 'ORG',
#   'sent_idx': 0,
#   'start': 34,
#   'end': 37,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'GovSpend',
#   'label': 'ORG',
#   'sent_idx': 4,
#   'start': 18,
#   'end': 19,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 5,
#   'start': 22,
#   'end': 24,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gaggle',
#   'label': 'ORG',
#   'sent_idx': 5,
#   'start': 25,
#   'end': 26,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'GoGuardian',
#   'label': 'PERSON',
#   'sent_idx': 5,
#   'start': 29,
#   'end': 30,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Carrollton-Farmers Branch',
#   'label': 'ORG',
#   'sent_idx': 7,
#   'start': 17,
#   'end': 21,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Coppell and Grapevine-Colleyville',
#   'label': 'ORG',
#   'sent_idx': 7,
#   'start': 26,
#   'end': 31,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 10,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gary Margolis',
#   'label': 'PERSON',
#   'sent_idx': 12,
#   'start': 5,
#   'end': 7,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Amelia Vance',
#   'label': 'PERSON',
#   'sent_idx': 13,
#   'start': 1,
#   'end': 3,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'the Future of Privacy Forum',
#   'label': 'ORG',
#   'sent_idx': 13,
#   'start': 12,
#   'end': 17,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Vance',
#   'label': 'PERSON',
#   'sent_idx': 14,
#   'start': 11,
#   'end': 12,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 27,
#   'end': 29,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'News',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 32,
#   'end': 33,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Securly’s Auditor',
#   'label': 'ORG',
#   'sent_idx': 17,
#   'start': 20,
#   'end': 23,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gaggle',
#   'label': 'ORG',
#   'sent_idx': 17,
#   'start': 24,
#   'end': 25,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gmail',
#   'label': 'PERSON',
#   'sent_idx': 17,
#   'start': 38,
#   'end': 39,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Google Docs',
#   'label': 'PERSON',
#   'sent_idx': 17,
#   'start': 40,
#   'end': 42,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Mike Jolley',
#   'label': 'PERSON',
#   'sent_idx': 18,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Securly',
#   'label': 'ORG',
#   'sent_idx': 18,
#   'start': 6,
#   'end': 7,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Jolley',
#   'label': 'PERSON',
#   'sent_idx': 19,
#   'start': 27,
#   'end': 28,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gaggle',
#   'label': 'PERSON',
#   'sent_idx': 20,
#   'start': 18,
#   'end': 19,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Carrollton-Farmers Branch ISD',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 0,
#   'end': 5,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gaggle',
#   'label': 'ORG',
#   'sent_idx': 21,
#   'start': 8,
#   'end': 9,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Dawn Parnell',
#   'label': 'PERSON',
#   'sent_idx': 22,
#   'start': 24,
#   'end': 26,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': '’s',
#   'label': 'ORG',
#   'sent_idx': 22,
#   'start': 29,
#   'end': 30,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Parnell',
#   'label': 'ORG',
#   'sent_idx': 24,
#   'start': 15,
#   'end': 16,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'GoGuardian’s',
#   'label': 'ORG',
#   'sent_idx': 25,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Jeff Gordon',
#   'label': 'PERSON',
#   'sent_idx': 28,
#   'start': 18,
#   'end': 20,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'GoGuardian’s',
#   'label': 'ORG',
#   'sent_idx': 28,
#   'start': 21,
#   'end': 23,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'GoGuardian’s',
#   'label': 'ORG',
#   'sent_idx': 29,
#   'start': 6,
#   'end': 8,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'the University of North Texas',
#   'label': 'ORG',
#   'sent_idx': 29,
#   'start': 38,
#   'end': 43,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 29,
#   'start': 44,
#   'end': 46,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Ed Reynolds',
#   'label': 'PERSON',
#   'sent_idx': 30,
#   'start': 3,
#   'end': 5,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Reynolds',
#   'label': 'ORG',
#   'sent_idx': 31,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'UNT',
#   'label': 'ORG',
#   'sent_idx': 31,
#   'start': 2,
#   'end': 3,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Stafford, Smyer',
#   'label': 'ORG',
#   'sent_idx': 33,
#   'start': 3,
#   'end': 6,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Blooming Grove',
#   'label': 'ORG',
#   'sent_idx': 33,
#   'start': 11,
#   'end': 13,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Rick Hartley',
#   'label': 'PERSON',
#   'sent_idx': 34,
#   'start': 12,
#   'end': 14,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Blooming Grove ISD',
#   'label': 'ORG',
#   'sent_idx': 34,
#   'start': 17,
#   'end': 20,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gaggle',
#   'label': 'ORG',
#   'sent_idx': 34,
#   'start': 23,
#   'end': 24,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gaggle',
#   'label': 'ORG',
#   'sent_idx': 35,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Jeff Patterson',
#   'label': 'PERSON',
#   'sent_idx': 35,
#   'start': 2,
#   'end': 4,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'The News',
#   'label': 'ORG',
#   'sent_idx': 37,
#   'start': 7,
#   'end': 9,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Patterson',
#   'label': 'ORG',
#   'sent_idx': 39,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gaggle',
#   'label': 'ORG',
#   'sent_idx': 39,
#   'start': 2,
#   'end': 3,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Securly',
#   'label': 'ORG',
#   'sent_idx': 41,
#   'start': 4,
#   'end': 5,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Jolley',
#   'label': 'ORG',
#   'sent_idx': 42,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel’s',
#   'label': 'ORG',
#   'sent_idx': 43,
#   'start': 1,
#   'end': 4,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Buzzfeed News',
#   'label': 'ORG',
#   'sent_idx': 44,
#   'start': 27,
#   'end': 29,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 46,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 46,
#   'start': 3,
#   'end': 5,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'the Center for Democracy and Technology',
#   'label': 'ORG',
#   'sent_idx': 47,
#   'start': 4,
#   'end': 10,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 48,
#   'start': 4,
#   'end': 6,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Buzzfeed News',
#   'label': 'ORG',
#   'sent_idx': 48,
#   'start': 8,
#   'end': 10,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Tammy Dowdy',
#   'label': 'PERSON',
#   'sent_idx': 49,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Dickinson ISD',
#   'label': 'ORG',
#   'sent_idx': 49,
#   'start': 7,
#   'end': 9,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'The News',
#   'label': 'ORG',
#   'sent_idx': 49,
#   'start': 11,
#   'end': 13,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 49,
#   'start': 21,
#   'end': 23,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'The Center for Democracy and Technology',
#   'label': 'ORG',
#   'sent_idx': 50,
#   'start': 0,
#   'end': 6,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'the National Suicide Hotline',
#   'label': 'ORG',
#   'sent_idx': 52,
#   'start': 8,
#   'end': 12,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Vance',
#   'label': 'PERSON',
#   'sent_idx': 52,
#   'start': 14,
#   'end': 15,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Schools',
#   'label': 'PERSON',
#   'sent_idx': 53,
#   'start': 22,
#   'end': 23,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 54,
#   'start': 5,
#   'end': 7,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Stephen F. Austin',
#   'label': 'PERSON',
#   'sent_idx': 54,
#   'start': 11,
#   'end': 14,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'State University',
#   'label': 'ORG',
#   'sent_idx': 54,
#   'start': 14,
#   'end': 16,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Criminal Legal News',
#   'label': 'ORG',
#   'sent_idx': 55,
#   'start': 3,
#   'end': 6,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'East Carolina University',
#   'label': 'ORG',
#   'sent_idx': 55,
#   'start': 10,
#   'end': 13,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'NBC News',
#   'label': 'ORG',
#   'sent_idx': 56,
#   'start': 4,
#   'end': 6,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'UNC-Chapel Hill',
#   'label': 'ORG',
#   'sent_idx': 56,
#   'start': 8,
#   'end': 12,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Confederate',
#   'label': 'ORG',
#   'sent_idx': 56,
#   'start': 35,
#   'end': 36,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'NBC',
#   'label': 'ORG',
#   'sent_idx': 57,
#   'start': 3,
#   'end': 4,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'UNC',
#   'label': 'ORG',
#   'sent_idx': 57,
#   'start': 6,
#   'end': 7,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 57,
#   'start': 8,
#   'end': 10,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 58,
#   'start': 5,
#   'end': 6,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 58,
#   'start': 15,
#   'end': 17,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'the University of Vermont',
#   'label': 'ORG',
#   'sent_idx': 58,
#   'start': 24,
#   'end': 28,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': '’s',
#   'label': 'ORG',
#   'sent_idx': 58,
#   'start': 41,
#   'end': 42,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Facebook',
#   'label': 'PERSON',
#   'sent_idx': 58,
#   'start': 53,
#   'end': 54,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': '’s',
#   'label': 'ORG',
#   'sent_idx': 59,
#   'start': 7,
#   'end': 8,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Aziz Huq',
#   'label': 'PERSON',
#   'sent_idx': 60,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'the University of Chicago',
#   'label': 'ORG',
#   'sent_idx': 60,
#   'start': 7,
#   'end': 11,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'U.S. Supreme Court',
#   'label': 'ORG',
#   'sent_idx': 61,
#   'start': 2,
#   'end': 5,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Stephen Breyer',
#   'label': 'PERSON',
#   'sent_idx': 63,
#   'start': 41,
#   'end': 43,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Emily Suski',
#   'label': 'PERSON',
#   'sent_idx': 65,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'the University of South Carolina',
#   'label': 'ORG',
#   'sent_idx': 65,
#   'start': 7,
#   'end': 12,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Breyer’s',
#   'label': 'ORG',
#   'sent_idx': 66,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Suski',
#   'label': 'PERSON',
#   'sent_idx': 66,
#   'start': 22,
#   'end': 23,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Harold Krent',
#   'label': 'PERSON',
#   'sent_idx': 68,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Chicago-Kent College of Law',
#   'label': 'ORG',
#   'sent_idx': 68,
#   'start': 7,
#   'end': 13,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Giovanni Capriglione',
#   'label': 'PERSON',
#   'sent_idx': 72,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'The News',
#   'label': 'ORG',
#   'sent_idx': 72,
#   'start': 11,
#   'end': 13,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Capriglione',
#   'label': 'PERSON',
#   'sent_idx': 73,
#   'start': 20,
#   'end': 21,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Clinton',
#   'label': 'PERSON',
#   'sent_idx': 74,
#   'start': 26,
#   'end': 27,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'the Children’s Internet Protection Act',
#   'label': 'ORG',
#   'sent_idx': 74,
#   'start': 32,
#   'end': 38,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Gaggle',
#   'label': 'ORG',
#   'sent_idx': 75,
#   'start': 5,
#   'end': 6,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'John Cornyn',
#   'label': 'PERSON',
#   'sent_idx': 76,
#   'start': 12,
#   'end': 14,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Cornyn',
#   'label': 'ORG',
#   'sent_idx': 77,
#   'start': 4,
#   'end': 5,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Cornyn',
#   'label': 'ORG',
#   'sent_idx': 79,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Cornyn',
#   'label': 'ORG',
#   'sent_idx': 80,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Greg Abbott',
#   'label': 'PERSON',
#   'sent_idx': 82,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 82,
#   'start': 3,
#   'end': 5,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Oxford',
#   'label': 'ORG',
#   'sent_idx': 84,
#   'start': 11,
#   'end': 12,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Vance',
#   'label': 'PERSON',
#   'sent_idx': 86,
#   'start': 35,
#   'end': 36,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Dallas Morning News',
#   'label': 'ORG',
#   'sent_idx': 87,
#   'start': 18,
#   'end': 21,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Lauren McGaughy',
#   'label': 'PERSON',
#   'sent_idx': 87,
#   'start': 23,
#   'end': 25,
#   'urls': 'https://www.dallasnews.com/news/investigations/2021/09/02/texas-schools-are-watching-millions-of-students-online-often-without-their-knowledge-or-consent/'},
#  {'name': 'Media Sonar',
#   'label': 'PERSON',
#   'sent_idx': 1,
#   'start': 2,
#   'end': 4,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 1,
#   'start': 5,
#   'end': 7,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Geofeedia',
#   'label': 'ORG',
#   'sent_idx': 1,
#   'start': 9,
#   'end': 10,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'WIRED',
#   'label': 'ORG',
#   'sent_idx': 4,
#   'start': 2,
#   'end': 3,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Eyal Feder-Levy',
#   'label': 'PERSON',
#   'sent_idx': 4,
#   'start': 5,
#   'end': 9,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Zencity',
#   'label': 'ORG',
#   'sent_idx': 5,
#   'start': 6,
#   'end': 7,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Brandon Talsma',
#   'label': 'PERSON',
#   'sent_idx': 6,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Zencity',
#   'label': 'ORG',
#   'sent_idx': 6,
#   'start': 24,
#   'end': 25,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Zencity’s',
#   'label': 'ORG',
#   'sent_idx': 7,
#   'start': 13,
#   'end': 15,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Brandon Talsma',
#   'label': 'PERSON',
#   'sent_idx': 8,
#   'start': 11,
#   'end': 13,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Grinnell',
#   'label': 'ORG',
#   'sent_idx': 9,
#   'start': 19,
#   'end': 20,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Talsma',
#   'label': 'PERSON',
#   'sent_idx': 10,
#   'start': 17,
#   'end': 18,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Talsma’s',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Talsma',
#   'label': 'ORG',
#   'sent_idx': 13,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Zencity',
#   'label': 'ORG',
#   'sent_idx': 13,
#   'start': 11,
#   'end': 12,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'NAACP',
#   'label': 'ORG',
#   'sent_idx': 14,
#   'start': 20,
#   'end': 21,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Betty Andrews',
#   'label': 'PERSON',
#   'sent_idx': 14,
#   'start': 22,
#   'end': 24,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Meltwater',
#   'label': 'PERSON',
#   'sent_idx': 17,
#   'start': 2,
#   'end': 3,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Brandwatch',
#   'label': 'ORG',
#   'sent_idx': 17,
#   'start': 4,
#   'end': 5,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Deb Gross',
#   'label': 'PERSON',
#   'sent_idx': 20,
#   'start': 6,
#   'end': 8,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Zencity',
#   'label': 'ORG',
#   'sent_idx': 20,
#   'start': 26,
#   'end': 27,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Facebook',
#   'label': 'PERSON',
#   'sent_idx': 21,
#   'start': 16,
#   'end': 17,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Twitter',
#   'label': 'PERSON',
#   'sent_idx': 21,
#   'start': 18,
#   'end': 19,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Sheriff Tony Spurlock',
#   'label': 'PERSON',
#   'sent_idx': 22,
#   'start': 32,
#   'end': 35,
#   'urls': 'https://www.wired.com/story/ai-helps-police-monitor-social-media-go-too-far/'},
#  {'name': 'Social Media Monitoring Tools Market',
#   'label': 'ORG',
#   'sent_idx': 0,
#   'start': 4,
#   'end': 9,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Key Features',
#   'label': 'PERSON',
#   'sent_idx': 6,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Social Media Monitoring Tools Research Report',
#   'label': 'ORG',
#   'sent_idx': 6,
#   'start': 3,
#   'end': 9,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Social Media Monitoring Tools',
#   'label': 'ORG',
#   'sent_idx': 6,
#   'start': 25,
#   'end': 29,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Social Media Monitoring Tools',
#   'label': 'ORG',
#   'sent_idx': 8,
#   'start': 11,
#   'end': 15,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Social Media Monitoring Tools',
#   'label': 'ORG',
#   'sent_idx': 10,
#   'start': 8,
#   'end': 12,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Sample Copy of Social Media Monitoring Tools Market with Complete TOC',
#   'label': 'ORG',
#   'sent_idx': 11,
#   'start': 2,
#   'end': 13,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Figures & Graphs',
#   'label': 'ORG',
#   'sent_idx': 11,
#   'start': 14,
#   'end': 17,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Research & Development',
#   'label': 'ORG',
#   'sent_idx': 11,
#   'start': 31,
#   'end': 34,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'DigitalStakeout',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 13,
#   'end': 14,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'SolarWinds',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 35,
#   'end': 36,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'CoNetrix',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 37,
#   'end': 38,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Crisp Thinking',
#   'label': 'PERSON',
#   'sent_idx': 12,
#   'start': 39,
#   'end': 41,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Brandle',
#   'label': 'PERSON',
#   'sent_idx': 12,
#   'start': 46,
#   'end': 48,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Hueya',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 50,
#   'end': 51,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'LookingGlass Cyber',
#   'label': 'PERSON',
#   'sent_idx': 12,
#   'start': 52,
#   'end': 54,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Digital',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 55,
#   'end': 56,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Trend Micro',
#   'label': 'PERSON',
#   'sent_idx': 12,
#   'start': 63,
#   'end': 65,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Micro Focus',
#   'label': 'PERSON',
#   'sent_idx': 12,
#   'start': 72,
#   'end': 74,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'CSC',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 75,
#   'end': 76,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Social Media Monitoring Tools Market Segmentation',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 90,
#   'end': 96,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Type',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 105,
#   'end': 106,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Application',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 108,
#   'end': 109,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Type',
#   'label': 'ORG',
#   'sent_idx': 13,
#   'start': 19,
#   'end': 20,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Application',
#   'label': 'ORG',
#   'sent_idx': 13,
#   'start': 22,
#   'end': 23,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'BFSI  Media & Entertainment',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 28,
#   'end': 33,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Telecommunication  Travel & Hospitality',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 34,
#   'end': 39,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Social Media Monitoring Tools Market',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 45,
#   'end': 50,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Asia Pacific (',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 100,
#   'end': 103,
#   'urls': 'https://liverpoolstudentmedia.com/uncategorised/712257/social-media-monitoring-tools-market-detailed-analysis-with-business-development-strategy-by-top-compnies/'},
#  {'name': 'Rest of Asia Pacific',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 112,
#   'end': 116,
# ...
#  {'name': 'Gary Margolis',
#   'label': 'PERSON',
#   'sent_idx': 2,
#   'start': 22,
#   'end': 24,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 3,
#   'start': 4,
#   'end': 6,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 6,
#   'start': 26,
#   'end': 28,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 7,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 8,
#   'start': 7,
#   'end': 9,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'the Burlington Free Press',
#   'label': 'ORG',
#   'sent_idx': 10,
#   'start': 4,
#   'end': 8,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 10,
#   'start': 13,
#   'end': 14,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 10,
#   'start': 24,
#   'end': 26,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'The American Civil Liberties Union',
#   'label': 'ORG',
#   'sent_idx': 11,
#   'start': 0,
#   'end': 5,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'the Brennan Center for Justice',
#   'label': 'ORG',
#   'sent_idx': 11,
#   'start': 6,
#   'end': 11,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'the New York University Law School',
#   'label': 'ORG',
#   'sent_idx': 11,
#   'start': 12,
#   'end': 18,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 11,
#   'start': 27,
#   'end': 28,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Burlington',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 9,
#   'end': 10,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': "SOCIAL MEDIA '",
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 12,
#   'end': 15,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'GlobalFoundries',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 31,
#   'end': 32,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Essex',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 40,
#   'end': 41,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 12,
#   'start': 45,
#   'end': 46,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'the Free Press',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 49,
#   'end': 52,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 12,
#   'start': 56,
#   'end': 58,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 13,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 14,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 14,
#   'start': 5,
#   'end': 7,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 4,
#   'end': 7,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Dealer.com',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 16,
#   'end': 17,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 15,
#   'start': 20,
#   'end': 21,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Rick Gibbs',
#   'label': 'PERSON',
#   'sent_idx': 16,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Dealer.com',
#   'label': 'ORG',
#   'sent_idx': 16,
#   'start': 7,
#   'end': 8,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 16,
#   'start': 10,
#   'end': 13,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 17,
#   'start': 4,
#   'end': 6,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Dealer.com',
#   'label': 'ORG',
#   'sent_idx': 17,
#   'start': 14,
#   'end': 15,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Contact Dan',
#   'label': 'PERSON',
#   'sent_idx': 18,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Twitter @DanDambrosioVT',
#   'label': 'PERSON',
#   'sent_idx': 19,
#   'start': 3,
#   'end': 5,
#   'urls': 'https://www.burlingtonfreepress.com/story/news/2019/10/30/social-sentinel-layoffs-expresses-future-growth-confidence-job-market/4095716002/'},
#  {'name': 'Superintendent Tim Broadrick',
#   'label': 'PERSON',
#   'sent_idx': 1,
#   'start': 31,
#   'end': 34,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'LobbyGuard',
#   'label': 'ORG',
#   'sent_idx': 3,
#   'start': 2,
#   'end': 3,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Shawsheen Tech',
#   'label': 'ORG',
#   'sent_idx': 6,
#   'start': 20,
#   'end': 22,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Broadrick',
#   'label': 'PERSON',
#   'sent_idx': 12,
#   'start': 21,
#   'end': 22,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 13,
#   'start': 0,
#   'end': 3,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Jesse Costa',
#   'label': 'PERSON',
#   'sent_idx': 13,
#   'start': 5,
#   'end': 7,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 13,
#   'start': 26,
#   'end': 28,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 15,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Tech',
#   'label': 'ORG',
#   'sent_idx': 16,
#   'start': 1,
#   'end': 2,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 17,
#   'start': 2,
#   'end': 4,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Broadrick',
#   'label': 'ORG',
#   'sent_idx': 17,
#   'start': 12,
#   'end': 13,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Gary Margolis',
#   'label': 'PERSON',
#   'sent_idx': 18,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 18,
#   'start': 3,
#   'end': 6,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 20,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Facebook',
#   'label': 'PERSON',
#   'sent_idx': 20,
#   'start': 21,
#   'end': 22,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 22,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 22,
#   'start': 37,
#   'end': 38,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'University of Vermont',
#   'label': 'ORG',
#   'sent_idx': 22,
#   'start': 49,
#   'end': 52,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Margolis',
#   'label': 'PERSON',
#   'sent_idx': 23,
#   'start': 44,
#   'end': 45,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Broadrick',
#   'label': 'ORG',
#   'sent_idx': 30,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 30,
#   'start': 9,
#   'end': 12,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Broadrick',
#   'label': 'PERSON',
#   'sent_idx': 31,
#   'start': 38,
#   'end': 39,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 35,
#   'start': 9,
#   'end': 11,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Fred Ryan',
#   'label': 'PERSON',
#   'sent_idx': 36,
#   'start': 3,
#   'end': 5,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Ryan',
#   'label': 'PERSON',
#   'sent_idx': 37,
#   'start': 14,
#   'end': 15,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Ryan',
#   'label': 'PERSON',
#   'sent_idx': 38,
#   'start': 11,
#   'end': 12,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Fred Ryan',
#   'label': 'PERSON',
#   'sent_idx': 41,
#   'start': 3,
#   'end': 5,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 41,
#   'start': 11,
#   'end': 13,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Jesse Costa',
#   'label': 'PERSON',
#   'sent_idx': 42,
#   'start': 1,
#   'end': 3,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 42,
#   'start': 10,
#   'end': 12,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 43,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Ryan',
#   'label': 'PERSON',
#   'sent_idx': 44,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Ryan',
#   'label': 'PERSON',
#   'sent_idx': 48,
#   'start': 12,
#   'end': 13,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Ryan',
#   'label': 'PERSON',
#   'sent_idx': 50,
#   'start': 1,
#   'end': 2,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 51,
#   'start': 0,
#   'end': 2,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Ryan',
#   'label': 'PERSON',
#   'sent_idx': 53,
#   'start': 8,
#   'end': 9,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Human Rights Commission',
#   'label': 'ORG',
#   'sent_idx': 54,
#   'start': 5,
#   'end': 8,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 54,
#   'start': 12,
#   'end': 14,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'the American Civil Liberties Union of Massachusetts',
#   'label': 'ORG',
#   'sent_idx': 55,
#   'start': 7,
#   'end': 14,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Kade Crockford',
#   'label': 'PERSON',
#   'sent_idx': 56,
#   'start': 33,
#   'end': 35,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'the Technology for Liberty Program',
#   'label': 'ORG',
#   'sent_idx': 56,
#   'start': 38,
#   'end': 43,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'ACLU',
#   'label': 'ORG',
#   'sent_idx': 56,
#   'start': 45,
#   'end': 46,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Crockford',
#   'label': 'ORG',
#   'sent_idx': 57,
#   'start': 0,
#   'end': 1,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'},
#  {'name': 'Social Sentinel',
#   'label': 'ORG',
#   'sent_idx': 59,
#   'start': 6,
#   'end': 9,
#   'urls': 'https://www.wbur.org/news/2018/03/22/school-threats-suicide-prevention-tech'}]

# %%
graph = {}

##Get news articles:
chrome_options = Options()
chrome_options.add_argument("--headless")
driver = webdriver.Chrome('/Users/arijitsen/Downloads/chromedriver')

driver.get('http://www.google.com')

search_query = driver.find_element_by_name('q')

search_query.send_keys('"Social Sentinel"')
sleep(5)
search_query.send_keys(Keys.RETURN)

news_urls = []

news_section = driver.find_elements_by_class_name('hdtb-mitem')
counter = 0
for i in news_section:
    if counter == 1:
        elements = i.find_elements_by_tag_name("a")
        for j in elements:
            x = j.get_attribute("href")
            driver.get(x)
        counter += 1
    else: 
        counter += 1

content_blocks = driver.find_elements_by_class_name('ftSUBd')

for block in content_blocks:
    elements = block.find_elements_by_tag_name("a")
    for el in elements:
        news_urls.append(el.get_attribute("href"))


try:
    while len(news_urls) < 30:
        next_button = driver.find_element_by_id('pnnext')
        next_button.click()
        news_section = driver.find_elements_by_class_name('hdtb-mitem')
        counter = 0
        for i in news_section:
            if counter == 1:
                elements = i.find_elements_by_tag_name("a")
                for j in elements:
                    x = j.get_attribute("href")
                    driver.get(x)
                counter += 1
            else: 
                counter += 1

        content_blocks = driver.find_elements_by_class_name('ftSUBd')

        for block in content_blocks:
            elements = block.find_elements_by_tag_name("a")
            for el in elements:
                news_urls.append(el.get_attribute("href"))
        sleep(5)
except:
    pass

driver.quit()
# Out:
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   # Remove the CWD from sys.path while we load stuff.
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py:359: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:42: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# /Users/arijitsen/opt/anaconda3/envs/anlp_spacy2/lib/python3.7/site-packages/ipykernel_launcher.py:54: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead

# %%
##Entity extraction 

#for each entity we need the entity type (person or org), the sentence index, the word index, the article its in, coreference chain 

nodes = []

urls = []
sent_idx = []
toke_idx = []

corefs = []
coref_idx = []
urls1 = []
for i in range(0, len(news_urls)):
    try:
        article = Article(news_urls[i])
        entities = []
        article.download()
        article.parse()
        article.nlp()


        #get the full text of the article
        text = article.text

        doc = nlp(text)

        tokenizer = nlp.tokenizer 

        sents = sent_tokenize(doc.text)
        
        counter = 0
        
        for j,k in enumerate(sents):

            x = tokenizer(k) #split sent into words
            
            sent_idx += len(x) * [j]

            for l in x:
                counter += 1
                toke_idx.append((counter - 1))
                urls.append(news_urls[i])
     
        

        
        for idx, chain in enumerate(doc._.coref_clusters):
            for mention in chain.mentions:
                coref_idx.append(idx)
                corefs.append(mention.start)
                urls1.append(news_urls[i])
                


        for k, l in enumerate(sents):

            #Use Spacy to extract all the entities from the sentence and them add them to the entities list
            entity = nlp(l)


            for ee in entity.ents:
                ent_dict = {}
                #we only want person or organization entities
                if ee.label_ == 'PERSON':
                    ent_dict['name'] = ee.text.replace('\n',' ').replace("’s'", "").strip()
                    ent_dict['label'] = ee.label_
                    ent_dict['sent_idx'] = k
                    ent_dict['start'] = ee.start
                    ent_dict['end'] = ee.end
                    ent_dict['urls'] = news_urls[i]
                    nodes.append(ent_dict)
                elif ee.label_ == 'ORG':
                    ent_dict['name'] = ee.text.replace('\n',' ').replace("’s", "").strip()
                    ent_dict['label'] = ee.label_
                    ent_dict['sent_idx'] = k 
                    ent_dict['start'] = ee.start
                    ent_dict['end'] = ee.end
                    ent_dict['urls'] = news_urls[i]
                    nodes.append(ent_dict)
                else:
                    pass
    except:
        pass

d =  {'sent_idx': sent_idx, 'toke_idx':toke_idx, 'urls':urls}
e = {'toke_idx':corefs, 'coref_idx': coref_idx, 'urls':urls1}
df = pd.DataFrame(d)
dfa = pd.DataFrame(e)
dfb  = pd.DataFrame(nodes)

# %%
dfb
# Out:
#                                                   name   label  sent_idx  \
# 0                         Social Media Security Market     ORG         1
# 1                                              Request     ORG         5
# 2                              Download Sample of This     ORG         5
# 3     Information and Communications Technology Market     ORG         6
# 4                                                  ICT     ORG         6
# ...                                                ...     ...       ...
# 1405                                           Edwards  PERSON        38
# 1406                                               RNZ     ORG        38
# 1407                                          Gavaghan     ORG        40
# 1408                                               OIA     ORG        40
# 1409                              Data Ethics Advisory     ORG        44
#
#       start  end                                               urls
# 0         0    4      https://www.taiwannews.com.tw/en/news/4377406
# 1         0    1      https://www.taiwannews.com.tw/en/news/4377406
# 2         2    6      https://www.taiwannews.com.tw/en/news/4377406
# 3        13   18      https://www.taiwannews.com.tw/en/news/4377406
# 4        19   20      https://www.taiwannews.com.tw/en/news/4377406
# ...     ...  ...                                                ...
# 1405     29   30  https://www.nzherald.co.nz/nz/police-tight-lip...
# 1406     31   32  https://www.nzherald.co.nz/nz/police-tight-lip...
# 1407      0    1  https://www.nzherald.co.nz/nz/police-tight-lip...
# 1408     24   25  https://www.nzherald.co.nz/nz/police-tight-lip...
# 1409     18   21  https://www.nzherald.co.nz/nz/police-tight-lip...
#
# [1410 rows x 6 columns]

# %%
links = []
for j in set(dfb['urls']): #filter to a single url
    df1a = dfb.loc[dfb['urls'] == j]
    for i in set(df1a['sent_idx']): #filter to that sentence
        link = {}
        df1 = df1a.loc[df1a['sent_idx'] == i]
        if len(df1) > 1:
            name1 = df1['name']
            name2 = df1['name']
            x = product(name1, name2)
            x = list(x)
            x = [k for k in x if k[0] !=  k[1]] #delete links where both nodes are the same
            x = list(unique_everseen(x, key=frozenset)) #delete reverse tuples
            x = [l for l in x if l[0] != '' and l[1] != ''] #delete links with empty strings
            
            if len(x) == 0:
                pass
            elif len(x) == 1:
                source = x[0][0]
                target = x[0][1]
                type1 = df1.loc[df1['name'] == source, 'label'].iloc[0]
                type2 = df1.loc[df1['name'] == target, 'label'].iloc[0]
                
                if type1 == 'ORG' and type2 == 'ORG':
                    pass
                else:
                    link['source'] = source
                    link['target'] = target
                    link['type'] = f'{type1}-{type2}'
                
                if link not in links:
                        links.append(link)
                else:
                    pass
            else:
                for m in range(0, len(x)):
                    source = x[m][0]
                    target = x[m][1]
                    type1 = df1.loc[df1['name'] == source, 'label'].iloc[0]
                    type2 = df1.loc[df1['name'] == target, 'label'].iloc[0]
                    if type1 == 'ORG' and type2 == 'ORG':
                        pass
                    else:
                        link['source'] = source
                        link['target'] = target
                        link['type'] = f'{type1}-{type2}'
                    
                    if link not in links:
                        links.append(link)
                    else:
                        pass
                    
        else:
            pass
print(len(links))
# Out:
# 204

# %%
df = pd.merge(df, dfa, how='inner', on=['toke_idx', 'urls']) #to get sent index for corefs

# %%
for i in set(urls):
    df2a = df.loc[df['urls'] == i]
    df3a = dfb.loc[df['urls'] == i]
    #get the sent_idx of every token with the same coref_idx
    for j in set(df2a['coref_idx']):
        df2 = df2a.loc[df2a['coref_idx'] == j]
        if len(set(df2['sent_idx'])) > 1:
            link  = {}
            coref_sents = list(set(df2['sent_idx']))
            df3 = df3a[df3a['sent_idx'].isin(coref_sents)]
            name1 = list(df3['name'])
            name2 = name1
            x = list(product(name1, name2))
            x = [k for k in x if k[0] !=  k[1]] #delete links where both nodes are the same
            x = list(unique_everseen(x, key=frozenset)) #delete reverse tuples
            x = [l for l in x if l[0] != '' and l[1] != ''] #delete links with empty strings
            
            if len(x) == 0:
                pass
            
            elif len(x) == 1:
                source = x[0][0]
                target = x[0][1]
                type1 = df3.loc[df3['name'] == source, 'label'].iloc[0]
                type2 = df3.loc[df3['name'] == target, 'label'].iloc[0]
                
                if type1 == 'ORG' and type2 == 'ORG':
                    pass
                else:
                    link['type'] = f'{type1}-{type2}'
                    link['target'] = x[0][1]
                    link['source'] = x[0][0]
                
                if link not in links:
                        links.append(link)
                else:
                    pass
            else:
                for m in range(0, len(x)):
                    source = x[m][0]
                    target = x[m][1]
                    type1 = df3.loc[df3['name'] == source, 'label'].iloc[0]
                    type2 = df3.loc[df3['name'] == target, 'label'].iloc[0]
                    
                    if type1 == 'ORG' and type2 == 'ORG':
                        pass
                    else:
                        link['type'] = f'{type1}-{type2}'
                        link['source'] = source
                        link['target'] = target
                        
                    
                    if link not in links:
                        links.append(link)
                    else:
                        pass
        else:
            pass
links = [link for link in links if link != {}]

# %%
graph['nodes'] = nodes
graph['links'] = links

# %%
with open("graph.json", "w") as outfile:
    json.dump(graph, outfile)

# %%
links_df = pd.DataFrame(links)
links_df.to_csv('links.csv', index=False)

# %%
dfb.to_csv('nodes.csv', index=False)
